# %%
import numpy as np
import pandas as pd
import seaborn as sn
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\zali2\tables2006.csv')

# %%
df
# Out:
#     Rank Field    name New  field  Disc          year Water  depth  (feet)  \
# 0    1.0         MC807        NaN              1989.0                3,393
# 1    2.0         EI330        NaN              1971.0                  247
# 2    3.0         WD030        NaN              1949.0                   48
# 3    4.0         MC778        NaN              1999.0                6,081
# 4    5.0         GI043        NaN              1956.0                  140
# 5    6.0         MC776          *              2000.0                5,662
# 6    7.0         BM002        NaN              1949.0                   50
# 7    8.0         GC743          *              1998.0                6,468
# 8    9.0         TS000        NaN              1958.0                   13
# 9   10.0         VR014        NaN              1956.0                   26
# 10  11.0         MP041        NaN              1956.0                   42
# ...
